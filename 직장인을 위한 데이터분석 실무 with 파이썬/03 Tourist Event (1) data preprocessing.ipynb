# %% [markdown]
# ### 데이터 전처리

# %%
import pandas as pd

# header = 1 : 두번째 줄에 칼럼명이 있음
# usecols = 'A:G' : A~G칼럼만 사용
# skipfooter = 4 : 아래에서 4줄은 사용하지 않음

kto_201901 = pd.read_excel('data/3_Tourists_Event/files/kto_201901.xlsx',\
                           header=1, usecols = 'A:G', skipfooter = 4)
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계
# 0  아시아주  765082  10837  1423  14087  125521  916950
# 1    일본  198805   2233   127    785    4576  206526
# 2    대만   86393     74    22    180    1285   87954
# 3    홍콩   34653     59     2     90    1092   35896
# 4   마카오    2506      2     0     17      45    2570

# %%
kto_201901.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %% [markdown]
# #### 데이터 탐색

# %%
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
# 데이터 값이 0인 레이블 확인
conditions = (kto_201901['관광'] == 0) | \
             (kto_201901['상용'] == 0) | \
             (kto_201901['공용'] == 0) | \
             (kto_201901['유학/연수'] == 0)

kto_201901[conditions]
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %% [markdown]
# #### 데이터 프레임에 기준연월 추가

# %%
kto_201901['기준연월'] = '2019-01'
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계     기준연월
# 0  아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1    일본  198805   2233   127    785    4576  206526  2019-01
# 2    대만   86393     74    22    180    1285   87954  2019-01
# 3    홍콩   34653     59     2     90    1092   35896  2019-01
# 4   마카오    2506      2     0     17      45    2570  2019-01

# %% [markdown]
# #### 국적 데이터만 남기기

# %%
# 칼럼이 어떤 정보로 이루어졌는지 확인하는 메쏘드 unique()
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
# 대륙 데이터를 리스트로 만듬
continents_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
continents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
# continents_list가 아닌 데이터만 선택
kto_201901_country = kto_201901[kto_201901['국적'].isin(continents_list)==False]
kto_201901_country['국적'].unique()
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
kto_201901_country.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준연월
# 1   일본  198805  2233  127    785  4576  206526  2019-01
# 2   대만   86393    74   22    180  1285   87954  2019-01
# 3   홍콩   34653    59    2     90  1092   35896  2019-01
# 4  마카오    2506     2    0     17    45    2570  2019-01
# 5   태국   34004    37  199     96  6998   41334  2019-01

# %%
# 인덱스 값 초기화
kto_201901_country_newindex = kto_201901_country.reset_index(drop = True)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준연월
# 0   일본  198805  2233  127    785  4576  206526  2019-01
# 1   대만   86393    74   22    180  1285   87954  2019-01
# 2   홍콩   34653    59    2     90  1092   35896  2019-01
# 3  마카오    2506     2    0     17    45    2570  2019-01
# 4   태국   34004    37  199     96  6998   41334  2019-01

# %% [markdown]
# #### 대륙 칼럼 만들기

# %%
continents = ['아시아']*25 + ['아메리카']*5 + ['유럽']*23 + ['오세아니아']*3 + ['아프리카']*2 + ['기타대륙'] + ['교포']
print(continents)
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아메리카', '아메리카', '아메리카', '아메리카', '아메리카', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '오세아니아', '오세아니아', '오세아니아', '아프리카', '아프리카', '기타대륙', '교포']

# %%
kto_201901_country_newindex['대륙'] = continents
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준연월   대륙
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아

# %%
kto_201901_country_newindex.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준연월     대륙
# 55    대양주 기타  555    3   4      0     52    614  2019-01  오세아니아
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01   아프리카
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01   아프리카
# 58      국적미상   33    4   0      1     16     54  2019-01   기타대륙
# 59        교포    0    0   0      0  15526  15526  2019-01     교포

# %% [markdown]
# #### 국적별 관광객 비율 살펴보기

# %%
kto_201901_country_newindex['관광객비율(%)'] = \
  round(kto_201901_country_newindex['관광'] / kto_201901_country_newindex['계'] * 100,1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준연월   대륙  관광객비율(%)
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3

# %%
# 관광객비율 칼럼을 내림차순으로 정렬하여 상위 5개국 확인
kto_201901_country_newindex.sort_values(by = '관광객비율(%)', ascending=False).head()
# Out:
#         국적      관광    상용   공용  유학/연수    기타       계     기준연월     대륙  관광객비율(%)
# 1       대만   86393    74   22    180  1285   87954  2019-01    아시아      98.2
# 3      마카오    2506     2    0     17    45    2570  2019-01    아시아      97.5
# 2       홍콩   34653    59    2     90  1092   35896  2019-01    아시아      96.5
# 0       일본  198805  2233  127    785  4576  206526  2019-01    아시아      96.3
# 55  대양주 기타     555     3    4      0    52     614  2019-01  오세아니아      90.4

# %%
# 관광객비율 칼럼을 오름차순으로 정렬하여 하위 5개국 확인
kto_201901_country_newindex.sort_values(by = '관광객비율(%)', ascending=True).head()
# Out:
#        국적   관광   상용  공용  유학/연수     기타      계     기준연월   대륙  관광객비율(%)
# 59     교포    0    0   0      0  15526  15526  2019-01   교포       0.0
# 14  방글라데시  149  126  27     97    848   1247  2019-01  아시아      11.9
# 12   스리랑카  157   54   5     28   1043   1287  2019-01  아시아      12.2
# 13   파키스탄  238  178  10    193    413   1032  2019-01  아시아      23.1
# 15   캄보디아  635   39  55     51   1915   2695  2019-01  아시아      23.6

# %%
kto_201901_country_newindex.pivot_table(values = '관광객비율(%)', index='대륙', aggfunc='mean')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
# 중국의 비율 확인
kto_201901_country_newindex[kto_201901_country_newindex['국적'] == '중국']
# Out:
#     국적      관광    상용   공용  유학/연수     기타       계     기준연월   대륙  관광객비율(%)
# 17  중국  320113  2993  138   8793  60777  392814  2019-01  아시아      81.5

# %% [markdown]
# #### 기준년월별로 전체 외국인 관광객 대비 국적별 관광객 비율 살펴보기

# %%
tourist_sum = sum(kto_201901_country_newindex['관광'])
tourist_sum
# Out:
# 884293

# %%
kto_201901_country_newindex['전체비율(%)'] = \
   round(kto_201901_country_newindex['관광'] / tourist_sum * 100, 1)
kto_201901_country_newindex.sort_values(by='전체비율(%)', ascending = False).head()
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준연월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     36.2
# 0      22.5
# 1       9.8
# 25      4.9
# 2       3.9

# %% [markdown]
# ### 데이터 전처리과정 함수로 만들기

# %%
def create_kto_data(yy,mm):
    # 1. 불러올 엑셀 파일 경로를 지정
    file_path = f'data/3_Tourists_Event/files/kto_{yy}{mm}.xlsx'
    
    # 2. 엑셀 파일 불러오기
    df = pd.read_excel(file_path, header=1, skipfooter=4, usecols='A:G')
    
    # 3. '기준년월' 칼럼 추가
    df['기준년월'] = f'{yy}-{mm}'
    
    # 4. '국적'칼럼에서 대륙 제거하고 국가만 남기기
    ignore_list = ['아시아주', '미주', '구주', '대양주', '아프리카주','기타대륙', '교포소계']
    df_country = df[df['국적'].isin(ignore_list)  == False].reset_index(drop=True)
    
    # 5. '대륙'칼럼 추가
    continents = ['아시아']*25 + ['아메리카']*5 + ['유럽']*23 + ['오세아니아']*3 + ['아프리카']*2 + ['기타대륙'] + ['교포']
    df_country['대륙'] = continents
    
    # 6. 국가별 '관광객비율(%)' 칼럼 추가
    df_country['관광객비율(%)'] = round(df_country['관광'] / df_country['계'] *100 ,1)
    
    # 7. '전체비율(%)' 칼럼 추가
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourist_sum * 100, 1)
    
    # 8. 결과출력
    return(df_country)

# %%
kto_test = create_kto_data(2018,12)
kto_test.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  252461  1698  161    608  3593  258521  2018-12  아시아      97.7
# 1   대만   85697    71   22    266  1252   87308  2018-12  아시아      98.2
# 2   홍콩   58355    41    3    208   939   59546  2018-12  아시아      98.0
# 3  마카오    6766     0    1     20    36    6823  2018-12  아시아      99.2
# 4   태국   47242    42  302     58  6382   54026  2018-12  아시아      87.4
#
#    전체비율(%)
# 0     22.7
# 1      7.7
# 2      5.2
# 3      0.6
# 4      4.2

# %% [markdown]
# ### 반복문을 통해 다수의 엑셀 데이터를 불러와서 합치기

# %%
for yy in range(2010,2020):
    for mm in range(1,13):
        # mm을 1이 아닌 01로 만들기 위해 zfill 메쏘드 활용
        # zfill 메쏘드는 문자열에만 적용가능
        mm_str = str(mm).zfill(2)
        yymm = f'{yy}{mm_str}'
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
# 데이터를 담을 빈 데이터프레임 만들기
df = pd.DataFrame()

# %%
for yy in range(2010,2020):
    for mm in range(1,13):
        temp = create_kto_data(str(yy), str(mm).zfill(2))
        df = df.append(temp, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-5d4dc6cdfbcc> in <module>
#       1 for yy in range(2010,2020):
#       2     for mm in range(1,13):
# ----> 3         temp = create_kto_data(str(yy), str(mm).zfill(2))
#       4         df = df.append(temp, ignore_index = True)
#
# <ipython-input-33-78434828b0bb> in create_kto_data(yy, mm)
#       4
#       5     # 2. 엑셀 파일 불러오기
# ----> 6     df = pd.read_excel(file_path, header=1, skipfooter=4, usecols='A:G')
#       7
#       8     # 3. '기준년월' 칼럼 추가
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
# ...

# %%
# 데이터 중 201909 엑셀이 없어서 생기는 오류
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
df.tail()
# Out:
#             국적    관광   상용   공용  유학/연수     기타      계     기준년월     대륙  관광객비율(%)  \
# 6955    대양주 기타   519    1    6      9     74    609  2019-08  오세아니아      85.2
# 6956  남아프리카공화국   634    6    1     11   1235   1887  2019-08   아프리카      33.6
# 6957   아프리카 기타  2081  593  165    841   1184   4864  2019-08   아프리카      42.8
# 6958      국적미상    36    1    0      8     12     57  2019-08   기타대륙      63.2
# 6959        교포     0    0    0      0  16560  16560  2019-08     교포       0.0
#
#       전체비율(%)
# 6955      0.0
# 6956      0.1
# 6957      0.2
# 6958      0.0
# 6959      0.0

# %%
for yy in range(2010,2020):
    for mm in range(1,13):
        # try 이하 구문을 실행
        try:
            temp = create_kto_data(str(yy), str(mm).zfill(2))
            df = df.append(temp, ignore_index = True)
        # 만약 try 구문에서 오류 발생시 except 이하 구문 실행
        except:
            pass

# %%
df.tail()
# Out:
#              국적    관광   상용   공용  유학/연수     기타      계     기준년월     대륙  \
# 13915    대양주 기타   519    1    6      9     74    609  2019-08  오세아니아
# 13916  남아프리카공화국   634    6    1     11   1235   1887  2019-08   아프리카
# 13917   아프리카 기타  2081  593  165    841   1184   4864  2019-08   아프리카
# 13918      국적미상    36    1    0      8     12     57  2019-08   기타대륙
# 13919        교포     0    0    0      0  16560  16560  2019-08     교포
#
#        관광객비율(%)  전체비율(%)
# 13915      85.2      0.0
# 13916      33.6      0.1
# 13917      42.8      0.2
# 13918      63.2      0.0
# 13919       0.0      0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13920 entries, 0 to 13919
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        13920 non-null  object
#  1   관광        13920 non-null  int64
#  2   상용        13920 non-null  int64
#  3   공용        13920 non-null  int64
#  4   유학/연수     13920 non-null  int64
#  5   기타        13920 non-null  int64
#  6   계         13920 non-null  int64
#  7   기준년월      13920 non-null  object
#  8   대륙        13920 non-null  object
#  9   관광객비율(%)  13920 non-null  float64
#  10  전체비율(%)   13920 non-null  float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# #### 통합테이터를 엑셀파일로 저장

# %%
df.to_excel('data/3_Tourists_Event/files/kto_total.xlsx',index=False)
